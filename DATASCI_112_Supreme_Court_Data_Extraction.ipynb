# %% [markdown]
# <a href="https://colab.research.google.com/github/KekaiApana/datasci112_final_project/blob/main/DATASCI_112_Supreme_Court_Data_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DATASCI 112 Final Project: Supreme Court Data Extraction**
# ### *By: Kekai and Adrian*
#
# This project explores the Cornell Supreme Court Oral Arguments Corpus (https://convokit.cornell.edu/documentation/supreme.html). This data includes data from cases spanning 1955 to 2019.
#
# Research questions:
# 1. Can we predict how the Justices in the Roberts Court will vote on a case based on their linguistic patterns in oral arguments and voting history?
# 2. Do certain justice’s have similar arguments and does that relate to how they vote?
#
#
# In this file, we extract data from different parts of the Corpus along with external JSON data and join it to form a single dataset we will be working with.

# %% [markdown]
# ### Step 1: Retrieve the data from the Cornell Supreme Court Oral Arguments Corpus

# %%
# !pip install convokit
# Out:
# Requirement already satisfied: convokit in /usr/local/lib/python3.11/dist-packages (3.1.0)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from convokit) (3.10.0)
# Requirement already satisfied: scipy>1.14 in /usr/local/lib/python3.11/dist-packages (from convokit) (1.14.1)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from convokit) (2.2.2)
# Requirement already satisfied: numpy>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from convokit) (2.0.2)
# Requirement already satisfied: msgpack-numpy>=0.4.3.2 in /usr/local/lib/python3.11/dist-packages (from convokit) (0.4.8)
# Requirement already satisfied: spacy>=3.8.2 in /usr/local/lib/python3.11/dist-packages (from convokit) (3.8.4)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.11/dist-packages (from convokit) (1.6.1)
# Requirement already satisfied: nltk>=3.4 in /usr/local/lib/python3.11/dist-packages (from convokit) (3.9.1)
# Requirement already satisfied: dill>=0.2.9 in /usr/local/lib/python3.11/dist-packages (from convokit) (0.3.8)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from convokit) (1.4.2)
# Requirement already satisfied: clean-text>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from convokit) (0.6.0)
# Requirement already satisfied: unidecode>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from convokit) (1.3.8)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from convokit) (4.67.1)
# Requirement already satisfied: pymongo>=4.0 in /usr/local/lib/python3.11/dist-packages (from convokit) (4.11.2)
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/local/lib/python3.11/dist-packages (from convokit) (6.0.2)
# Requirement already satisfied: dnspython>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from convokit) (2.7.0)
# Requirement already satisfied: thinc<8.4.0,>=8.3.0 in /usr/local/lib/python3.11/dist-packages (from convokit) (8.3.4)
# Requirement already satisfied: h5py==3.12.1 in /usr/local/lib/python3.11/dist-packages (from convokit) (3.12.1)
# Requirement already satisfied: numexpr>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from convokit) (2.10.2)
# Requirement already satisfied: ruff>=0.4.8 in /usr/local/lib/python3.11/dist-packages (from convokit) (0.11.0)
# Requirement already satisfied: bottleneck in /usr/local/lib/python3.11/dist-packages (from convokit) (1.4.2)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (from convokit) (1.3.0)
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (from convokit) (0.14.0)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.11/dist-packages (from convokit) (0.45.3)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from convokit) (4.48.3)
# Requirement already satisfied: trl>=0.12.2 in /usr/local/lib/python3.11/dist-packages (from convokit) (0.15.2)
# Requirement already satisfied: tensorflow>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from convokit) (2.18.0)
# Requirement already satisfied: tf-keras<3.0.0,>=2.17.0 in /usr/local/lib/python3.11/dist-packages (from convokit) (2.18.0)
# Requirement already satisfied: emoji<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from clean-text>=0.6.0->convokit) (1.7.0)
# Requirement already satisfied: ftfy<7.0,>=6.0 in /usr/local/lib/python3.11/dist-packages (from clean-text>=0.6.0->convokit) (6.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->convokit) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->convokit) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->convokit) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->convokit) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->convokit) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->convokit) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->convokit) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->convokit) (2.8.2)
# Requirement already satisfied: msgpack>=0.5.2 in /usr/local/lib/python3.11/dist-packages (from msgpack-numpy>=0.4.3.2->convokit) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>=3.4->convokit) (8.1.8)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>=3.4->convokit) (2024.11.6)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->convokit) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->convokit) (2025.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0->convokit) (3.5.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy>=3.8.2->convokit) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=3.8.2->convokit) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=3.8.2->convokit) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy>=3.8.2->convokit) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy>=3.8.2->convokit) (3.0.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy>=3.8.2->convokit) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy>=3.8.2->convokit) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy>=3.8.2->convokit) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=3.8.2->convokit) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=3.8.2->convokit) (0.15.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=3.8.2->convokit) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy>=3.8.2->convokit) (2.10.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy>=3.8.2->convokit) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy>=3.8.2->convokit) (75.1.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=3.8.2->convokit) (3.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.18.0->convokit) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.18.0->convokit) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.18.0->convokit) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.18.0->convokit) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.18.0->convokit) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.18.0->convokit) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.18.0->convokit) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.18.0->convokit) (4.25.6)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.18.0->convokit) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.18.0->convokit) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.18.0->convokit) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.18.0->convokit) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.18.0->convokit) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.18.0->convokit) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.18.0->convokit) (3.8.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.18.0->convokit) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.18.0->convokit) (0.37.1)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.0->convokit) (1.2.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.0->convokit) (0.1.5)
# Requirement already satisfied: datasets>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from trl>=0.12.2->convokit) (3.4.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from trl>=0.12.2->convokit) (13.9.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate->convokit) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate->convokit) (2.6.0+cu124)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate->convokit) (0.28.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate->convokit) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers->convokit) (3.17.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers->convokit) (0.21.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow>=2.18.0->convokit) (0.45.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl>=0.12.2->convokit) (18.1.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl>=0.12.2->convokit) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl>=0.12.2->convokit) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets>=2.21.0->trl>=0.12.2->convokit) (2024.10.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl>=0.12.2->convokit) (3.11.13)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy<7.0,>=6.0->clean-text>=0.6.0->convokit) (0.2.13)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.18.0->convokit) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.18.0->convokit) (0.14.1)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy>=3.8.2->convokit) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.8.2->convokit) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.8.2->convokit) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.8.2->convokit) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.8.2->convokit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.8.2->convokit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.8.2->convokit) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.18.0->convokit) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.18.0->convokit) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.18.0->convokit) (3.1.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->convokit) (3.4.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->convokit) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->convokit) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->convokit) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->convokit) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->convokit) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->convokit) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->convokit) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->convokit) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->convokit) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->convokit) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->convokit) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->convokit) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->convokit) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->convokit) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->convokit) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate->convokit) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy>=3.8.2->convokit) (1.5.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl>=0.12.2->convokit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl>=0.12.2->convokit) (2.18.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy>=3.8.2->convokit) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy>=3.8.2->convokit) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy>=3.8.2->convokit) (3.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl>=0.12.2->convokit) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl>=0.12.2->convokit) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl>=0.12.2->convokit) (25.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl>=0.12.2->convokit) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl>=0.12.2->convokit) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl>=0.12.2->convokit) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl>=0.12.2->convokit) (1.18.3)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=3.8.2->convokit) (1.2.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->trl>=0.12.2->convokit) (0.1.2)

# %%
from convokit import Corpus, download
import pandas as pd

corpus = Corpus(filename=download("supreme-corpus"))
corpus
# Out:
# Dataset already exists at /root/.convokit/saved-corpora/supreme-corpus

# %% [markdown]
# Looking into the corpus, we have utterances, or small pieces of what a justice said during a case. Let's look at a example below.

# %%
utt = corpus.random_utterance()

# %%
print("ID:", utt.id, "\n")
print("Reply_to:", utt.reply_to, "\n")
print("Timestamp:", utt.timestamp, "\n")
print("Text:", utt.text, "\n")
print("Conversation ID:", utt.conversation_id, "\n")
print("Speaker ID:", utt.speaker.id)
# Out:
# ID: 19741__2_006
#
# Reply_to: 19741__2_005
#
# Timestamp: None
#
# Text: We would draw the line, Justice Scalia, on the function and we think what function is the actor, insurance company in this instance, performing?
# If it is performing a compulsorily, an ERISA-mandated function, in this instance claims administration, we would say that that was ERISA and preemption applied.
#
# Conversation ID: 19741
#
# Speaker ID: john_e_nolan_jr

# %% [markdown]
# ### Step 2: Get all utterances from the corpus and clean the data

# %%
df_utterances = corpus.get_utterances_dataframe()
df_utterances
# Out:
#              timestamp                                               text  \
# id
# 13127__0_000      None  Number 71, Lonnie Affronti versus United State...
# 13127__0_001      None  May it please the Court.\nWe are here by writ ...
# 13127__0_002      None                             Consecutive sentences.
# 13127__0_003      None  Consecutive sentences.\nIn this case, the defe...
# 13127__0_004      None  Was the aggregate prison sentence was 20 or 25...
# ...                ...                                                ...
# 24969__2_007      None  -- has all sorts of meaning that you're not en...
# 24969__2_008      None                                  No, Your Honor --
# 24969__2_009      None                                     -- altogether?
# 24969__2_010      None  -- we are using the principles of complicity a...
# 24969__2_011      None        Thank you, counsel.\nThe case is submitted.
#
#                            speaker      reply_to conversation_id meta.case_id  \
# id
# 13127__0_000        j__earl_warren          None           13127      1955_71
# 13127__0_001        harry_f_murphy  13127__0_000           13127      1955_71
# 13127__0_002  j__william_o_douglas  13127__0_001           13127      1955_71
# 13127__0_003        harry_f_murphy  13127__0_002           13127      1955_71
# 13127__0_004           <INAUDIBLE>  13127__0_003           13127      1955_71
# ...                            ...           ...             ...          ...
# 24969__2_007    j__sonia_sotomayor  24969__2_006           24969   2019_19-67
# 24969__2_008         eric_j_feigin  24969__2_007           24969   2019_19-67
# 24969__2_009    j__sonia_sotomayor  24969__2_008           24969   2019_19-67
# 24969__2_010         eric_j_feigin  24969__2_009           24969   2019_19-67
# 24969__2_011  j__john_g_roberts_jr  24969__2_010           24969   2019_19-67
#
#                                                meta.start_times  \
# id
# 13127__0_000                                       [0.0, 7.624]
# 13127__0_001    [9.218, 11.538, 15.653, 22.722, 28.849, 33.575]
# 13127__0_002                                           [48.138]
# 13127__0_003  [49.315, 51.844, 60.81, 67.083, 72.584, 89.839...
# 13127__0_004                                          [174.058]
# ...                                                         ...
# 24969__2_007                [3496.8, 3500.32, 3502.96, 3504.68]
# 24969__2_008                                          [3506.04]
# 24969__2_009                                          [3506.56]
# 24969__2_010                                  [3507.76, 3535.8]
# 24969__2_011                                 [3536.32, 3537.28]
#
#                                                 meta.stop_times  \
# id
# 13127__0_000                                     [7.624, 9.218]
# 13127__0_001   [11.538, 15.653, 22.722, 28.849, 33.575, 48.138]
# 13127__0_002                                           [49.315]
# 13127__0_003  [51.844, 60.81, 67.083, 72.584, 89.839, 95.873...
# 13127__0_004                                          [176.766]
# ...                                                         ...
# 24969__2_007               [3500.32, 3502.96, 3504.68, 3506.04]
# 24969__2_008                                          [3506.56]
# 24969__2_009                                          [3507.76]
# 24969__2_010                                  [3535.8, 3536.32]
# 24969__2_011                                     [3537.28, 0.0]
#
#              meta.speaker_type meta.side meta.timestamp vectors
# id
# 13127__0_000                 J      None            0.0      []
# 13127__0_001                 A         1          9.218      []
# 13127__0_002                 J      None         48.138      []
# 13127__0_003                 A         1         49.315      []
# 13127__0_004              None      None        174.058      []
# ...                        ...       ...            ...     ...
# 24969__2_007                 J      None         3496.8      []
# 24969__2_008                 A         1        3506.04      []
# 24969__2_009                 J      None        3506.56      []
# 24969__2_010                 A         1        3507.76      []
# 24969__2_011                 J      None        3536.32      []
#
# [1700789 rows x 12 columns]

# %%
# Filters the data to include only the justices
df_utt_justices = df_utterances[df_utterances["meta.speaker_type"] == "J"]

# Drops any unnecessary columns
columns = ["timestamp", "conversation_id", "meta.start_times", "meta.stop_times", "meta.side", "meta.timestamp", "vectors"]
df_utt_justices = df_utt_justices.drop(columns=columns)

# Reconfigures the columns to be more organized
df_utt_justices["utt_id"] = df_utt_justices.index
df_utt_justices = df_utt_justices.iloc[:, [5, 0, 1, 2, 3, 4]]
df_utt_justices
# Out:
#                     utt_id                                               text  \
# id
# 13127__0_000  13127__0_000  Number 71, Lonnie Affronti versus United State...
# 13127__0_002  13127__0_002                             Consecutive sentences.
# 13127__0_008  13127__0_008  Mr. Murphy, what statutory language do you rel...
# 13127__0_010  13127__0_010                                              3651?
# 13127__0_012  13127__0_012  What language there do you rely on to support ...
# ...                    ...                                                ...
# 24969__2_003  24969__2_003  -- what in reading this statute would give an ...
# 24969__2_005  24969__2_005                        But accomplice liability --
# 24969__2_007  24969__2_007  -- has all sorts of meaning that you're not en...
# 24969__2_009  24969__2_009                                     -- altogether?
# 24969__2_011  24969__2_011        Thank you, counsel.\nThe case is submitted.
#
#                            speaker      reply_to meta.case_id  \
# id
# 13127__0_000        j__earl_warren          None      1955_71
# 13127__0_002  j__william_o_douglas  13127__0_001      1955_71
# 13127__0_008        j__earl_warren  13127__0_007      1955_71
# 13127__0_010        j__earl_warren  13127__0_009      1955_71
# 13127__0_012        j__earl_warren  13127__0_011      1955_71
# ...                            ...           ...          ...
# 24969__2_003    j__sonia_sotomayor  24969__2_002   2019_19-67
# 24969__2_005    j__sonia_sotomayor  24969__2_004   2019_19-67
# 24969__2_007    j__sonia_sotomayor  24969__2_006   2019_19-67
# 24969__2_009    j__sonia_sotomayor  24969__2_008   2019_19-67
# 24969__2_011  j__john_g_roberts_jr  24969__2_010   2019_19-67
#
#              meta.speaker_type
# id
# 13127__0_000                 J
# 13127__0_002                 J
# 13127__0_008                 J
# 13127__0_010                 J
# 13127__0_012                 J
# ...                        ...
# 24969__2_003                 J
# 24969__2_005                 J
# 24969__2_007                 J
# 24969__2_009                 J
# 24969__2_011                 J
#
# [787417 rows x 6 columns]

# %% [markdown]
# ### Step 3: Get the data for all SCOTUS cases and clean the data

# %%
url = "https://zissou.infosci.cornell.edu/convokit/datasets/supreme-corpus/cases.jsonl"
df_cases = pd.read_json(url, lines=True)
df_cases
# Out:
#                 id  year    citation  \
# 0          1955_71  1955   350 US 79
# 1         1955_410  1955   351 US 79
# 2         1955_351  1955  350 US 532
# 3          1955_38  1955  350 US 568
# 4          1955_49  1955  350 US 198
# ...            ...   ...         ...
# 7743    2019_19-46  2019    591 US _
# 7744   2019_19-177  2019    591 US _
# 7745  2019_18-1584  2019    590 US _
# 7746    2019_19-67  2019    590 US _
# 7747   2019_19-373  2019        None
#
#                                                   title  \
# 0                             Affronti v. United States
# 1     American Airlines, Inc. v. North American Airl...
# 2                                  Archawski v. Hanioti
# 3                                Armstrong v. Armstrong
# 4     Bernhardt v. Polygraphic Company of America, Inc.
# ...                                                 ...
# 7743  U.S. Patent and Trademark Office v. Booking.co...
# 7744  United States Agency for International Develop...
# 7745  United States Forest Service v. Cowpasture Riv...
# 7746                    United States v. Sineneng-Smith
# 7747                            Walker v. United States
#
#                                              petitioner  \
# 0                                              Affronti
# 1                               American Airlines, Inc.
# 2                                             Archawski
# 3                                             Armstrong
# 4                                             Bernhardt
# ...                                                 ...
# 7743          United States Patent and Trademark Office
# 7744  United States Agency for International Develop...
# 7745               United States Forest Service, et al.
# 7746                           United States of America
# 7747                                       James Walker
#
#                                              respondent docket_no  \
# 0                                         United States        71
# 1                         North American Airlines, Inc.       410
# 2                                               Hanioti       351
# 3                                             Armstrong        38
# 4                  Polygraphic Company of America, Inc.        49
# ...                                                 ...       ...
# 7743                                   Booking.com B.V.     19-46
# 7744  Alliance for Open Society International, Inc.,...    19-177
# 7745               Cowpasture River Association, et al.   18-1584
# 7746                              Evelyn Sineneng-Smith     19-67
# 7747                           United States of America    19-373
#
#               court  decided_date                                      url  \
# 0      Warren Court   Dec 5, 1955       https://www.oyez.org/cases/1955/71
# 1      Warren Court  Apr 23, 1956      https://www.oyez.org/cases/1955/410
# 2      Warren Court   Apr 9, 1956      https://www.oyez.org/cases/1955/351
# 3      Warren Court   Apr 9, 1956       https://www.oyez.org/cases/1955/38
# 4      Warren Court  Jan 16, 1956       https://www.oyez.org/cases/1955/49
# ...             ...           ...                                      ...
# 7743  Roberts Court  Jun 30, 2020    https://www.oyez.org/cases/2019/19-46
# 7744  Roberts Court  Jun 29, 2020   https://www.oyez.org/cases/2019/19-177
# 7745  Roberts Court  Jun 15, 2020  https://www.oyez.org/cases/2019/18-1584
# 7746  Roberts Court   May 7, 2020    https://www.oyez.org/cases/2019/19-67
# 7747           None          None   https://www.oyez.org/cases/2019/19-373
#
#       ... adv_sides_inferred  known_respondent_adv  \
# 0     ...               True                  True
# 1     ...               True                  True
# 2     ...               True                 False
# 3     ...               True                 False
# 4     ...               True                 False
# ...   ...                ...                   ...
# 7743  ...              False                  True
# 7744  ...              False                  True
# 7745  ...              False                  True
# 7746  ...              False                  True
# 7747  ...              False                 False
#
#                                               advocates win_side  \
# 0     {'Harry F. Murphy': {'id': 'harry_f_murphy', '...      0.0
# 1     {'Howard C. Westwood': {'id': 'howard_c_westwo...      1.0
# 2     {'Harry D. Graham': {'id': 'harry_d_graham', '...      1.0
# 3     {'Robert N. Gorman': {'id': 'robert_n_gorman',...      0.0
# 4     {'Manfred W. Ehrich, Jr.': {'id': 'manfred_w_e...      1.0
# ...                                                 ...      ...
# 7743  {'Erica L. Ross': {'id': 'erica_l_ross', 'name...      0.0
# 7744  {'Christopher G. Michel': {'id': 'christopher_...      1.0
# 7745  {'Anthony A. Yang': {'id': 'anthony_a_yang', '...      1.0
# 7746  {'Eric J. Feigin': {'id': 'eric_j_feigin', 'na...      1.0
# 7747                                                 {}      NaN
#
#       win_side_detail  scdb_docket_id  \
# 0                 2.0     1955-009-01
# 1                 4.0     1955-071-01
# 2                 4.0     1955-053-01
# 3                 2.0     1955-056-01
# 4                 4.0     1955-020-01
# ...               ...             ...
# 7743              2.0     2019-049-01
# 7744              3.0     2019-052-01
# 7745              4.0     2019-041-01
# 7746              5.0     2019-043-01
# 7747              NaN            None
#
#                                                   votes  \
# 0     {'j__john_m_harlan2': 2.0, 'j__hugo_l_black': ...
# 1     {'j__john_m_harlan2': 2.0, 'j__hugo_l_black': ...
# 2     {'j__john_m_harlan2': 2.0, 'j__hugo_l_black': ...
# 3     {'j__john_m_harlan2': 2.0, 'j__hugo_l_black': ...
# 4     {'j__john_m_harlan2': 1.0, 'j__hugo_l_black': ...
# ...                                                 ...
# 7743  {'j__john_g_roberts_jr': 2.0, 'j__clarence_tho...
# 7744  {'j__john_g_roberts_jr': 2.0, 'j__clarence_tho...
# 7745  {'j__john_g_roberts_jr': 2.0, 'j__clarence_tho...
# 7746  {'j__john_g_roberts_jr': 2.0, 'j__clarence_tho...
# 7747                                               None
#
#                                            votes_detail is_eq_divided  \
# 0     {'j__john_m_harlan2': 1.0, 'j__hugo_l_black': ...           0.0
# 1     {'j__john_m_harlan2': 1.0, 'j__hugo_l_black': ...           0.0
# 2     {'j__john_m_harlan2': 1.0, 'j__hugo_l_black': ...           0.0
# 3     {'j__john_m_harlan2': 1.0, 'j__hugo_l_black': ...           0.0
# 4     {'j__john_m_harlan2': 2.0, 'j__hugo_l_black': ...           0.0
# ...                                                 ...           ...
# 7743  {'j__john_g_roberts_jr': 1.0, 'j__clarence_tho...           0.0
# 7744  {'j__john_g_roberts_jr': 1.0, 'j__clarence_tho...           0.0
# 7745  {'j__john_g_roberts_jr': 1.0, 'j__clarence_tho...           0.0
# 7746  {'j__john_g_roberts_jr': 1.0, 'j__clarence_tho...           0.0
# 7747                                               None           NaN
#
#                                              votes_side
# 0     {'j__john_m_harlan2': 0.0, 'j__hugo_l_black': ...
# 1     {'j__john_m_harlan2': 1.0, 'j__hugo_l_black': ...
# 2     {'j__john_m_harlan2': 1.0, 'j__hugo_l_black': ...
# 3     {'j__john_m_harlan2': 0.0, 'j__hugo_l_black': ...
# 4     {'j__john_m_harlan2': 0.0, 'j__hugo_l_black': ...
# ...                                                 ...
# 7743  {'j__john_g_roberts_jr': 0.0, 'j__clarence_tho...
# 7744  {'j__john_g_roberts_jr': 1.0, 'j__clarence_tho...
# 7745  {'j__john_g_roberts_jr': 1.0, 'j__clarence_tho...
# 7746  {'j__john_g_roberts_jr': 1.0, 'j__clarence_tho...
# 7747                                               None
#
# [7748 rows x 21 columns]

# %%
# Drops unnecessary columns
caseCols = ["citation", "petitioner", "respondent", "docket_no", "decided_date", "url", "transcripts",
            "adv_sides_inferred", "known_respondent_adv", "advocates", "win_side", "win_side_detail",
            "scdb_docket_id", "is_eq_divided", "votes_detail"]
df_cases_clean = df_cases.drop(columns=caseCols)

# Filters data to include only Roberts Court cases
df_cases_clean = df_cases_clean[df_cases_clean["court"] == "Roberts Court"]

# Renames case id column in preparation for data merge
df_cases_clean.rename(columns={"id": "meta.case_id"}, inplace=True)
df_cases_clean
# Out:
#        meta.case_id  year                                              title  \
# 6573  2005_128-orig  2005                            Alaska v. United States
# 6574    2005_04-433  2005             Anza v. Ideal Steel Supply Corporation
# 6575    2005_04-944  2005                             Arbaugh v. Y & H Corp.
# 6576    2005_8-orig  2005                              Arizona v. California
# 6577   2005_04-1506  2005  Arkansas Dept. of Health and Human Servs. v. A...
# ...             ...   ...                                                ...
# 7742    2019_19-635  2019                                     Trump v. Vance
# 7743     2019_19-46  2019  U.S. Patent and Trademark Office v. Booking.co...
# 7744    2019_19-177  2019  United States Agency for International Develop...
# 7745   2019_18-1584  2019  United States Forest Service v. Cowpasture Riv...
# 7746     2019_19-67  2019                    United States v. Sineneng-Smith
#
#               court                                              votes  \
# 6573  Roberts Court  {'j__john_paul_stevens': 2.0, 'j__sandra_day_o...
# 6574  Roberts Court  {'j__john_paul_stevens': 2.0, 'j__antonin_scal...
# 6575  Roberts Court  {'j__john_paul_stevens': 2.0, 'j__antonin_scal...
# 6576  Roberts Court  {'j__john_paul_stevens': 2.0, 'j__antonin_scal...
# 6577  Roberts Court  {'j__john_paul_stevens': 2.0, 'j__antonin_scal...
# ...             ...                                                ...
# 7742  Roberts Court  {'j__john_g_roberts_jr': 2.0, 'j__clarence_tho...
# 7743  Roberts Court  {'j__john_g_roberts_jr': 2.0, 'j__clarence_tho...
# 7744  Roberts Court  {'j__john_g_roberts_jr': 2.0, 'j__clarence_tho...
# 7745  Roberts Court  {'j__john_g_roberts_jr': 2.0, 'j__clarence_tho...
# 7746  Roberts Court  {'j__john_g_roberts_jr': 2.0, 'j__clarence_tho...
#
#                                              votes_side
# 6573  {'j__john_paul_stevens': 0.0, 'j__sandra_day_o...
# 6574  {'j__john_paul_stevens': 1.0, 'j__antonin_scal...
# 6575  {'j__john_paul_stevens': 1.0, 'j__antonin_scal...
# 6576  {'j__john_paul_stevens': 0.0, 'j__antonin_scal...
# 6577  {'j__john_paul_stevens': 0.0, 'j__antonin_scal...
# ...                                                 ...
# 7742  {'j__john_g_roberts_jr': 0.0, 'j__clarence_tho...
# 7743  {'j__john_g_roberts_jr': 0.0, 'j__clarence_tho...
# 7744  {'j__john_g_roberts_jr': 1.0, 'j__clarence_tho...
# 7745  {'j__john_g_roberts_jr': 1.0, 'j__clarence_tho...
# 7746  {'j__john_g_roberts_jr': 1.0, 'j__clarence_tho...
#
# [1167 rows x 6 columns]

# %%
# Expands votes column
votes_expanded = df_cases_clean['votes'].apply(pd.Series)
votes_expanded = votes_expanded.add_prefix('votes.')

# Expands votes_side column
votes_side_expanded = df_cases_clean['votes_side'].apply(pd.Series)
votes_side_expanded = votes_side_expanded.add_prefix('votes_side.')

# Combines data into one dataframe
df_expanded = pd.concat([df_cases_clean.drop(columns=['votes', 'votes_side']), votes_expanded, votes_side_expanded], axis=1)
df_expanded
# Out:
#        meta.case_id  year                                              title  \
# 6573  2005_128-orig  2005                            Alaska v. United States
# 6574    2005_04-433  2005             Anza v. Ideal Steel Supply Corporation
# 6575    2005_04-944  2005                             Arbaugh v. Y & H Corp.
# 6576    2005_8-orig  2005                              Arizona v. California
# 6577   2005_04-1506  2005  Arkansas Dept. of Health and Human Servs. v. A...
# ...             ...   ...                                                ...
# 7742    2019_19-635  2019                                     Trump v. Vance
# 7743     2019_19-46  2019  U.S. Patent and Trademark Office v. Booking.co...
# 7744    2019_19-177  2019  United States Agency for International Develop...
# 7745   2019_18-1584  2019  United States Forest Service v. Cowpasture Riv...
# 7746     2019_19-67  2019                    United States v. Sineneng-Smith
#
#               court  votes.j__john_paul_stevens  votes.j__sandra_day_oconnor  \
# 6573  Roberts Court                         2.0                          2.0
# 6574  Roberts Court                         2.0                          NaN
# 6575  Roberts Court                         2.0                          NaN
# 6576  Roberts Court                         2.0                          NaN
# 6577  Roberts Court                         2.0                          NaN
# ...             ...                         ...                          ...
# 7742  Roberts Court                         NaN                          NaN
# 7743  Roberts Court                         NaN                          NaN
# 7744  Roberts Court                         NaN                          NaN
# 7745  Roberts Court                         NaN                          NaN
# 7746  Roberts Court                         NaN                          NaN
#
#       votes.j__antonin_scalia  votes.j__anthony_m_kennedy  \
# 6573                      2.0                         2.0
# 6574                      2.0                         2.0
# 6575                      2.0                         2.0
# 6576                      2.0                         2.0
# 6577                      2.0                         2.0
# ...                       ...                         ...
# 7742                      NaN                         NaN
# 7743                      NaN                         NaN
# 7744                      NaN                         NaN
# 7745                      NaN                         NaN
# 7746                      NaN                         NaN
#
#       votes.j__david_h_souter  votes.j__clarence_thomas  ...  \
# 6573                      2.0                       2.0  ...
# 6574                      2.0                       2.0  ...
# 6575                      2.0                       2.0  ...
# 6576                      2.0                       2.0  ...
# 6577                      2.0                       2.0  ...
# ...                       ...                       ...  ...
# 7742                      NaN                       1.0  ...
# 7743                      NaN                       2.0  ...
# 7744                      NaN                       2.0  ...
# 7745                      NaN                       2.0  ...
# 7746                      NaN                       2.0  ...
#
#       votes_side.j__david_h_souter  votes_side.j__clarence_thomas  \
# 6573                           0.0                            0.0
# 6574                           1.0                            1.0
# 6575                           1.0                            1.0
# 6576                           0.0                            0.0
# 6577                           0.0                            0.0
# ...                            ...                            ...
# 7742                           NaN                            1.0
# 7743                           NaN                            0.0
# 7744                           NaN                            1.0
# 7745                           NaN                            1.0
# 7746                           NaN                            1.0
#
#       votes_side.j__ruth_bader_ginsburg  votes_side.j__stephen_g_breyer  \
# 6573                                0.0                             0.0
# 6574                                1.0                             1.0
# 6575                                1.0                             1.0
# 6576                                0.0                             0.0
# 6577                                0.0                             0.0
# ...                                 ...                             ...
# 7742                                0.0                             0.0
# 7743                                0.0                             1.0
# 7744                                0.0                             0.0
# 7745                                1.0                             1.0
# 7746                                1.0                             1.0
#
#       votes_side.j__john_g_roberts_jr  votes_side.j__samuel_a_alito_jr  \
# 6573                              NaN                              NaN
# 6574                              1.0                              1.0
# 6575                              1.0                              NaN
# 6576                              0.0                              0.0
# 6577                              0.0                              0.0
# ...                               ...                              ...
# 7742                              0.0                              1.0
# 7743                              0.0                              0.0
# 7744                              1.0                              1.0
# 7745                              1.0                              1.0
# 7746                              1.0                              1.0
#
#       votes_side.j__sonia_sotomayor  votes_side.j__elena_kagan  \
# 6573                            NaN                        NaN
# 6574                            NaN                        NaN
# 6575                            NaN                        NaN
# 6576                            NaN                        NaN
# 6577                            NaN                        NaN
# ...                             ...                        ...
# 7742                            0.0                        0.0
# 7743                            0.0                        0.0
# 7744                            0.0                        NaN
# 7745                            0.0                        0.0
# 7746                            1.0                        1.0
#
#       votes_side.j__neil_gorsuch  votes_side.j__brett_m_kavanaugh
# 6573                         NaN                              NaN
# 6574                         NaN                              NaN
# 6575                         NaN                              NaN
# 6576                         NaN                              NaN
# 6577                         NaN                              NaN
# ...                          ...                              ...
# 7742                         0.0                              0.0
# 7743                         0.0                              0.0
# 7744                         1.0                              1.0
# 7745                         1.0                              1.0
# 7746                         1.0                              1.0
#
# [1167 rows x 32 columns]

# %% [markdown]
# ### Step 4: Merge the data

# %%
df_merge = df_utt_justices.merge(df_expanded, how="inner", on="meta.case_id")
df_merge
# Out:
#               utt_id                                               text  \
# 0       22620__0_000  We'll hear argument first this morning in 04-4...
# 1       22620__0_002  Well, isn't there something different here?\nB...
# 2       22620__0_004  Sure, but they suffered the harm because the f...
# 3       22620__0_006  Well, why... why is that true?\nLet's assume t...
# 4       22620__0_008  Mr. Frederick, you... you started by saying ho...
# ...              ...                                                ...
# 125912  24969__2_003  -- what in reading this statute would give an ...
# 125913  24969__2_005                        But accomplice liability --
# 125914  24969__2_007  -- has all sorts of meaning that you're not en...
# 125915  24969__2_009                                     -- altogether?
# 125916  24969__2_011        Thank you, counsel.\nThe case is submitted.
#
#                        speaker      reply_to meta.case_id meta.speaker_type  \
# 0         j__john_g_roberts_jr          None  2005_04-433                 J
# 1            j__david_h_souter  22620__0_001  2005_04-433                 J
# 2            j__david_h_souter  22620__0_003  2005_04-433                 J
# 3         j__anthony_m_kennedy  22620__0_005  2005_04-433                 J
# 4       j__ruth_bader_ginsburg  22620__0_007  2005_04-433                 J
# ...                        ...           ...          ...               ...
# 125912      j__sonia_sotomayor  24969__2_002   2019_19-67                 J
# 125913      j__sonia_sotomayor  24969__2_004   2019_19-67                 J
# 125914      j__sonia_sotomayor  24969__2_006   2019_19-67                 J
# 125915      j__sonia_sotomayor  24969__2_008   2019_19-67                 J
# 125916    j__john_g_roberts_jr  24969__2_010   2019_19-67                 J
#
#         year                                   title          court  \
# 0       2005  Anza v. Ideal Steel Supply Corporation  Roberts Court
# 1       2005  Anza v. Ideal Steel Supply Corporation  Roberts Court
# 2       2005  Anza v. Ideal Steel Supply Corporation  Roberts Court
# 3       2005  Anza v. Ideal Steel Supply Corporation  Roberts Court
# 4       2005  Anza v. Ideal Steel Supply Corporation  Roberts Court
# ...      ...                                     ...            ...
# 125912  2019         United States v. Sineneng-Smith  Roberts Court
# 125913  2019         United States v. Sineneng-Smith  Roberts Court
# 125914  2019         United States v. Sineneng-Smith  Roberts Court
# 125915  2019         United States v. Sineneng-Smith  Roberts Court
# 125916  2019         United States v. Sineneng-Smith  Roberts Court
#
#         votes.j__john_paul_stevens  ...  votes_side.j__david_h_souter  \
# 0                              2.0  ...                           1.0
# 1                              2.0  ...                           1.0
# 2                              2.0  ...                           1.0
# 3                              2.0  ...                           1.0
# 4                              2.0  ...                           1.0
# ...                            ...  ...                           ...
# 125912                         NaN  ...                           NaN
# 125913                         NaN  ...                           NaN
# 125914                         NaN  ...                           NaN
# 125915                         NaN  ...                           NaN
# 125916                         NaN  ...                           NaN
#
#         votes_side.j__clarence_thomas  votes_side.j__ruth_bader_ginsburg  \
# 0                                 1.0                                1.0
# 1                                 1.0                                1.0
# 2                                 1.0                                1.0
# 3                                 1.0                                1.0
# 4                                 1.0                                1.0
# ...                               ...                                ...
# 125912                            1.0                                1.0
# 125913                            1.0                                1.0
# 125914                            1.0                                1.0
# 125915                            1.0                                1.0
# 125916                            1.0                                1.0
#
#         votes_side.j__stephen_g_breyer  votes_side.j__john_g_roberts_jr  \
# 0                                  1.0                              1.0
# 1                                  1.0                              1.0
# 2                                  1.0                              1.0
# 3                                  1.0                              1.0
# 4                                  1.0                              1.0
# ...                                ...                              ...
# 125912                             1.0                              1.0
# 125913                             1.0                              1.0
# 125914                             1.0                              1.0
# 125915                             1.0                              1.0
# 125916                             1.0                              1.0
#
#         votes_side.j__samuel_a_alito_jr  votes_side.j__sonia_sotomayor  \
# 0                                   1.0                            NaN
# 1                                   1.0                            NaN
# 2                                   1.0                            NaN
# 3                                   1.0                            NaN
# 4                                   1.0                            NaN
# ...                                 ...                            ...
# 125912                              1.0                            1.0
# 125913                              1.0                            1.0
# 125914                              1.0                            1.0
# 125915                              1.0                            1.0
# 125916                              1.0                            1.0
#
#         votes_side.j__elena_kagan  votes_side.j__neil_gorsuch  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
# ...                           ...                         ...
# 125912                        1.0                         1.0
# 125913                        1.0                         1.0
# 125914                        1.0                         1.0
# 125915                        1.0                         1.0
# 125916                        1.0                         1.0
#
#         votes_side.j__brett_m_kavanaugh
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 125912                              1.0
# 125913                              1.0
# 125914                              1.0
# 125915                              1.0
# 125916                              1.0
#
# [125917 rows x 37 columns]

# %%
df_merge.to_csv("scotus_roberts_data.csv", index=False)
