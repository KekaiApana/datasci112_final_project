# %% [markdown]
# <a href="https://colab.research.google.com/github/KekaiApana/datasci112_final_project/blob/main/DATASCI_112_Supreme_Court_Data_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DATASCI 112 Final Project: Supreme Court Data Exploration**
# ### *By: Kekai and Adrian*
#
# This project explores the Cornell Supreme Court Oral Arguments Corpus (https://convokit.cornell.edu/documentation/supreme.html). This data includes data from cases spanning 1955 to 2019.
#
# **Research question: Can we predict how Chief Justice Roberts will vote on a case based on their linguistic patterns in oral arguments?**
#
# In this file, we analyze the linguistic patterns of Chief Justice Roberts and other Justices during oral arguments to explore whether these patterns correlate with their voting behavior. Specifically, we:
#
# Visualize Voting Similarity: Create a heatmap to show how often each pair of Justices votes the same way, highlighting patterns of agreement or disagreement.
#
# Analyze Linguistic Patterns: Use text analysis techniques to identify the most frequently used words by each Justice during oral arguments.
#
# Correlate Words and Voting: Explore the relationship between the words used by Justices and their voting behavior, using scatter plots and bar charts.
#
# Heatmap: Shows word usage by Justices.
#
# Bar Chart: Displays top words for each Justice and their voting similarity.

# %%
pip install -U kaleido
# Out:
# Requirement already satisfied: kaleido in /usr/local/lib/python3.11/dist-packages (0.2.1)

# %%
import pandas as pd
df = pd.read_csv('scotus_roberts_data.csv')

# %%
import plotly.express as px

# Create a pivot table to count the number of times each pair of Justices votes the same way
vote_columns = [col for col in df.columns if col.startswith('votes_side.j__')]
justices = [col.split('__')[-1] for col in vote_columns]

# Create a matrix to store the number of times each pair of Justices votes the same way
vote_matrix = pd.DataFrame(index=justices, columns=justices)

for i, justice1 in enumerate(justices):
    for j, justice2 in enumerate(justices):
        if i == j:
            vote_matrix.loc[justice1, justice2] = 1  # A Justice always votes with themselves
        else:
            # Count the number of times both Justices voted the same way
            same_votes = df[f'votes_side.j__{justice1}'] == df[f'votes_side.j__{justice2}']
            vote_matrix.loc[justice1, justice2] = same_votes.mean()

# Convert the matrix to a long format for plotting
vote_matrix_long = vote_matrix.stack().reset_index()
vote_matrix_long.columns = ['Justice1', 'Justice2', 'Vote Similarity']

# Create a heatmap
fig = px.imshow(vote_matrix,
                labels=dict(x="Justice", y="Justice", color="Vote Similarity"),
                x=justices, y=justices,
                title="Voting Similarity Among Justices in the Roberts Court")

fig.update_layout(
        width = 800,
        height = 800,
        title_font=dict(size=24),
        xaxis=dict(
            title_font=dict(size=24),
            tickfont=dict(size=24)
        ),
        yaxis=dict(
            title_font=dict(size=24),
            tickfont=dict(size=24)
        )
    )


# Save the figure as a PNG file
fig.write_image("voting_similarity_heatmap.png")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="03450e17-7910-4e12-b874-e9342661fa34" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03450e17-7910-4e12-b874-e9342661fa34")) {                    Plotly.newPlot(                        "03450e17-7910-4e12-b874-e9342661fa34",                        [{"coloraxis":"coloraxis","name":"0","x":["john_paul_stevens","sandra_day_oconnor","antonin_scalia","anthony_m_kennedy","david_h_souter","clarence_thomas","ruth_bader_ginsburg","stephen_g_breyer","john_g_roberts_jr","samuel_a_alito_jr","sonia_sotomayor","elena_kagan","neil_gorsuch","brett_m_kavanaugh"],"y":["john_paul_stevens","sandra_day_oconnor","antonin_scalia","anthony_m_kennedy","david
...

# %%
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

# Extract the text and speaker columns
texts = df['text']
speakers = df['speaker']

# Create a CountVectorizer to count the frequency of words
vectorizer = CountVectorizer(stop_words='english', max_features=100)
X = vectorizer.fit_transform(texts)

# Convert the sparse matrix to a DataFrame
word_freq_df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
word_freq_df['speaker'] = speakers

# Group by speaker and sum the word frequencies
speaker_word_freq = word_freq_df.groupby('speaker').sum()

# Normalize the word frequencies by the total number of words spoken by each Justice
speaker_word_freq = speaker_word_freq.div(speaker_word_freq.sum(axis=1), axis=0)

# Now, we can correlate the word frequencies with the voting patterns
# For simplicity, let's just visualize the top 10 words for each Justice
top_words_per_justice = speaker_word_freq.apply(lambda x: x.nlargest(10).index.tolist(), axis=1)

# Create a bar chart for each Justice's top words
i = 1
for justice in top_words_per_justice.index:
    fig = px.bar(speaker_word_freq.loc[justice].nlargest(10),
                 title=f"Top 10 Words for {justice}",
                 labels={
            'index': 'Words',
            'value': 'Frequency'
        })

    fig.update_layout(
        width = 800,
        height = 800,
        title_font=dict(size=24),
        xaxis=dict(
            title_font=dict(size=24),
            tickfont=dict(size=24)
        ),
        yaxis=dict(
            title_font=dict(size=24),
            tickfont=dict(size=24)
        )
    )
    fig.write_image(f"top_words_justice{i}.png")
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b7cb9bd8-e2cc-4695-8188-ff5248be6935" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7cb9bd8-e2cc-4695-8188-ff5248be6935")) {                    Plotly.newPlot(                        "b7cb9bd8-e2cc-4695-8188-ff5248be6935",                        [{"alignmentgroup":"True","hovertemplate":"variable=j__anthony_m_kennedy\u003cbr\u003eWords=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"j__anthony_m_kennedy","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"j__anthony_m_kennedy","offsetgroup":"j__anthony_m_kennedy","orientation":"v","showlegend":true,"textposition":"auto","x":["case","just","say","think","court","question","don","state","justice","suppose"],"xaxis":"x","y":[0.047497928038638504,0.04318253265125318,0.037781143722671544,0.028921722728701665,0.028007201851904775,0.02743562630390672,0.027206996084707495,0.02480637878311566,0.024149066902917894,0.021033980166328483],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type": ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6222a249-c37f-4443-aa72-b8e08902a2f5" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6222a249-c37f-4443-aa72-b8e08902a2f5")) {                    Plotly.newPlot(                        "6222a249-c37f-4443-aa72-b8e08902a2f5",                        [{"alignmentgroup":"True","hovertemplate":"variable=j__antonin_scalia\u003cbr\u003eWords=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"j__antonin_scalia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"j__antonin_scalia","offsetgroup":"j__antonin_scalia","orientation":"v","showlegend":true,"textposition":"auto","x":["don","say","know","mean","right","think","just","case","court","state"],"xaxis":"x","y":[0.04566270438275993,0.041380792566997865,0.0335939954039711,0.03238712450609222,0.031527435647329176,0.030485889529981647,0.02818787508059583,0.024484599996693505,0.023013209449964454,0.022252715459520227],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marke ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="201b364a-9500-4ad9-b6f8-82889400cace" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("201b364a-9500-4ad9-b6f8-82889400cace")) {                    Plotly.newPlot(                        "201b364a-9500-4ad9-b6f8-82889400cace",                        [{"alignmentgroup":"True","hovertemplate":"variable=j__brett_m_kavanaugh\u003cbr\u003eWords=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"j__brett_m_kavanaugh","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"j__brett_m_kavanaugh","offsetgroup":"j__brett_m_kavanaugh","orientation":"v","showlegend":true,"textposition":"auto","x":["justice","think","just","question","said","right","say","going","congress","state"],"xaxis":"x","y":[0.04584426946631671,0.04321959755030621,0.03937007874015748,0.032720909886264214,0.027821522309711286,0.026596675415573052,0.025721784776902887,0.025546806649168852,0.022747156605424323,0.02204724409448819],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="
"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d891ecc4-8a64-469c-bce8-ca24ced5da50" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d891ecc4-8a64-469c-bce8-ca24ced5da50")) {                    Plotly.newPlot(                        "d891ecc4-8a64-469c-bce8-ca24ced5da50",                        [{"alignmentgroup":"True","hovertemplate":"variable=j__neil_gorsuch\u003cbr\u003eWords=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"j__neil_gorsuch","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"j__neil_gorsuch","offsetgroup":"j__neil_gorsuch","orientation":"v","showlegend":true,"textposition":"auto","x":["just","right","question","court","think","say","don","justice","case","law"],"xaxis":"x","y":[0.04445684523809524,0.04408482142857143,0.028459821428571428,0.02734375,0.026320684523809524,0.025576636904761904,0.022135416666666668,0.021205357142857144,0.020647321428571428,0.02027529761904762],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorb ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0a7c62fa-4ed8-4618-b426-a0e42798a570" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0a7c62fa-4ed8-4618-b426-a0e42798a570")) {                    Plotly.newPlot(                        "0a7c62fa-4ed8-4618-b426-a0e42798a570",                        [{"alignmentgroup":"True","hovertemplate":"variable=j__ruth_bader_ginsburg\u003cbr\u003eWords=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"j__ruth_bader_ginsburg","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"j__ruth_bader_ginsburg","offsetgroup":"j__ruth_bader_ginsburg","orientation":"v","showlegend":true,"textposition":"auto","x":["court","case","said","say","state","just","question","mr","don","think"],"xaxis":"x","y":[0.04647179506484218,0.038830017504564364,0.03728660430273485,0.03523499407103465,0.02390408251613996,0.023489996047356434,0.023489996047356434,0.02228538086544072,0.021683073274482864,0.01949970825726063],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"sc ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a46e4dae-21b8-4fdd-bc08-248fb96fa216" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a46e4dae-21b8-4fdd-bc08-248fb96fa216")) {                    Plotly.newPlot(                        "a46e4dae-21b8-4fdd-bc08-248fb96fa216",                        [{"alignmentgroup":"True","hovertemplate":"variable=j__samuel_a_alito_jr\u003cbr\u003eWords=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"j__samuel_a_alito_jr","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"j__samuel_a_alito_jr","offsetgroup":"j__samuel_a_alito_jr","orientation":"v","showlegend":true,"textposition":"auto","x":["say","case","think","court","don","state","going","question","just","does"],"xaxis":"x","y":[0.032914845782706446,0.03144971834187991,0.028317376916664562,0.02771111728597772,0.026397554752822898,0.024199863591583097,0.02397251623007553,0.023214691691716978,0.023164170055826407,0.021800085886781014],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scat ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a9d464c2-770f-42f4-be04-f526de9f2870" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9d464c2-770f-42f4-be04-f526de9f2870")) {                    Plotly.newPlot(                        "a9d464c2-770f-42f4-be04-f526de9f2870",                        [{"alignmentgroup":"True","hovertemplate":"variable=j__sandra_day_oconnor\u003cbr\u003eWords=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"j__sandra_day_oconnor","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"j__sandra_day_oconnor","offsetgroup":"j__sandra_day_oconnor","orientation":"v","showlegend":true,"textposition":"auto","x":["court","case","don","think","say","just","law","rule","yes","does"],"xaxis":"x","y":[0.06158357771260997,0.04398826979472141,0.036656891495601175,0.03372434017595308,0.02785923753665689,0.026392961876832845,0.02346041055718475,0.02346041055718475,0.02346041055718475,0.021994134897360705],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolar ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="12ffdb6a-54b7-4539-b646-7a5ba35ab4b6" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12ffdb6a-54b7-4539-b646-7a5ba35ab4b6")) {                    Plotly.newPlot(                        "12ffdb6a-54b7-4539-b646-7a5ba35ab4b6",                        [{"alignmentgroup":"True","hovertemplate":"variable=j__sonia_sotomayor\u003cbr\u003eWords=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"j__sonia_sotomayor","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"j__sonia_sotomayor","offsetgroup":"j__sonia_sotomayor","orientation":"v","showlegend":true,"textposition":"auto","x":["don","court","think","question","just","going","say","right","said","know"],"xaxis":"x","y":[0.03938941294428189,0.028135294960201347,0.026191401853860163,0.02565938900370363,0.025025065990055453,0.024104274518630682,0.02400196435513904,0.023940578257044053,0.022794704425937673,0.022528698000859406],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolar ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0d5c8d40-1b7c-4499-a793-a054b684e916" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d5c8d40-1b7c-4499-a793-a054b684e916")) {                    Plotly.newPlot(                        "0d5c8d40-1b7c-4499-a793-a054b684e916",                        [{"alignmentgroup":"True","hovertemplate":"variable=j__stephen_g_breyer\u003cbr\u003eWords=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"j__stephen_g_breyer","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"j__stephen_g_breyer","offsetgroup":"j__stephen_g_breyer","orientation":"v","showlegend":true,"textposition":"auto","x":["say","don","think","right","know","just","case","says","mean","want"],"xaxis":"x","y":[0.0445056205551732,0.033825291223777115,0.03175210080463579,0.031284783292124425,0.03073249895915645,0.027206375910207064,0.02680703185406099,0.02362077608693805,0.02267764437986966,0.022346273780088875],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","m ...

# %%
# Here, we just visualize the top words for each Justice and their voting similarity
# Now, correlate the top words with voting similarity
for justice in top_words_per_justice.index:
    # Remove the 'j__' prefix from the justice name to match the vote_matrix
    justice_name = justice.split('__')[-1]

    print(f"Top words for {justice}: {top_words_per_justice[justice]}")
    print(f"Voting similarity with other Justices: {vote_matrix.loc[justice_name]}")
# Out:
# Top words for j__anthony_m_kennedy: ['case', 'just', 'say', 'think', 'court', 'question', 'don', 'state', 'justice', 'suppose']
# Voting similarity with other Justices: john_paul_stevens      0.235552
# sandra_day_oconnor     0.019441
# antonin_scalia         0.547067
# anthony_m_kennedy             1
# david_h_souter         0.196304
# clarence_thomas        0.652057
# ruth_bader_ginsburg    0.611045
# stephen_g_breyer       0.638595
# john_g_roberts_jr      0.723548
# samuel_a_alito_jr      0.670593
# sonia_sotomayor        0.413836
# elena_kagan            0.356783
# neil_gorsuch           0.063963
# brett_m_kavanaugh           0.0
# Name: anthony_m_kennedy, dtype: object
# Top words for j__antonin_scalia: ['don', 'say', 'know', 'mean', 'right', 'think', 'just', 'case', 'court', 'state']
# Voting similarity with other Justices: john_paul_stevens      0.201029
# sandra_day_oconnor     0.020998
# antonin_scalia                1
# anthony_m_kennedy      0.547067
# david_h_souter         0.171002
# clarence_thomas        0.620504
# ruth_bader_ginsburg    0.418363
# stephen_g_breyer       0.404179
# john_g_roberts_jr      0.608695
# samuel_a_alito_jr      0.549219
# sonia_sotomayor        0.246154
# elena_kagan             0.19354
# neil_gorsuch                0.0
# brett_m_kavanaugh           0.0
# Name: antonin_scalia, dtype: object
# Top words for j__brett_m_kavanaugh: ['justice', 'think', 'just', 'question', 'said', 'right', 'say', 'going', 'congress', 'state']
# Voting similarity with other Justices: john_paul_stevens           0.0
# sandra_day_oconnor          0.0
# antonin_scalia              0.0
# anthony_m_kennedy           0.0
# david_h_souter              0.0
# clarence_thomas        0.095174
# ruth_bader_ginsburg    0.070753
# stephen_g_breyer       0.076836
# john_g_roberts_jr       0.10549
# samuel_a_alito_jr       0.10248
# sonia_sotomayor        0.066862
# elena_kagan            0.076606
# neil_gorsuch           0.094173
# brett_m_kavanaugh             1
# Name: brett_m_kavanaugh, dtype: object
# Top words for j__clarence_thomas: ['thank', 'case', 'mr', 'just', 'think', 'yes', 'justice', 'question', 'like', 'counsel']
# Voting similarity with other Justices: john_paul_stevens      0.182493
# sandra_day_oconnor     0.018536
# antonin_scalia         0.620504
# anthony_m_kennedy      0.652057
# david_h_souter         0.158017
# clarence_thomas               1
# ruth_bader_ginsburg    0.546336
# stephen_g_breyer       0.561664
# john_g_roberts_jr      0.800837
# samuel_a_alito_jr       0.81132
# sonia_sotomayor        0.381275
# elena_kagan            0.345577
# neil_gorsuch           0.161368
# brett_m_kavanaugh      0.095174
# Name: clarence_thomas, dtype: object
# Top words for j__david_h_souter: ['case', 'don', 'say', 'question', 'argument', 'going', 'isn', 'court', 'saying', 'state']
# Voting similarity with other Justices: john_paul_stevens      0.247083
# sandra_day_oconnor     0.022562
# antonin_scalia         0.171002
# anthony_m_kennedy      0.196304
# david_h_souter                1
# clarence_thomas        0.158017
# ruth_bader_ginsburg     0.25296
# stephen_g_breyer       0.242326
# john_g_roberts_jr      0.177379
# samuel_a_alito_jr      0.137448
# sonia_sotomayor             0.0
# elena_kagan                 0.0
# neil_gorsuch                0.0
# brett_m_kavanaugh           0.0
# Name: david_h_souter, dtype: object
# Top words for j__elena_kagan: ['just', 'mr', 'think', 'say', 'know', 'question', 'mean', 'right', 'said', 'case']
# Voting similarity with other Justices: john_paul_stevens           0.0
# sandra_day_oconnor          0.0
# antonin_scalia          0.19354
# anthony_m_kennedy      0.356783
# david_h_souter              0.0
# clarence_thomas        0.345577
# ruth_bader_ginsburg    0.525449
# stephen_g_breyer       0.521288
# john_g_roberts_jr      0.414344
# samuel_a_alito_jr      0.356378
# sonia_sotomayor        0.515204
# elena_kagan                   1
# neil_gorsuch           0.125313
# brett_m_kavanaugh      0.076606
# Name: elena_kagan, dtype: object
# Top words for j__john_g_roberts_jr: ['mr', 'case', 'thank', 'counsel', 'say', 'don', 'know', 'going', 'just', 'right']
# Voting similarity with other Justices: john_paul_stevens      0.207915
# sandra_day_oconnor     0.019521
# antonin_scalia         0.608695
# anthony_m_kennedy      0.723548
# david_h_souter         0.177379
# clarence_thomas        0.800837
# ruth_bader_ginsburg    0.640763
# stephen_g_breyer        0.67967
# john_g_roberts_jr             1
# samuel_a_alito_jr       0.81213
# sonia_sotomayor         0.46641
# elena_kagan            0.414344
# neil_gorsuch           0.157707
# brett_m_kavanaugh       0.10549
# Name: john_g_roberts_jr, dtype: object
# Top words for j__john_paul_stevens: ['question', 'case', 'just', 'ask', 'think', 'say', 'don', 'statute', 'understand', 'does']
# Voting similarity with other Justices: john_paul_stevens             1
# sandra_day_oconnor     0.019656
# antonin_scalia         0.201029
# anthony_m_kennedy      0.235552
# david_h_souter         0.247083
# clarence_thomas        0.182493
# ruth_bader_ginsburg    0.305733
# stephen_g_breyer       0.303668
# john_g_roberts_jr      0.207915
# samuel_a_alito_jr      0.170684
# sonia_sotomayor        0.060524
# elena_kagan                 0.0
# neil_gorsuch                0.0
# brett_m_kavanaugh           0.0
# Name: john_paul_stevens, dtype: object
# Top words for j__neil_gorsuch: ['just', 'right', 'question', 'court', 'think', 'say', 'don', 'justice', 'case', 'law']
# Voting similarity with other Justices: john_paul_stevens           0.0
# sandra_day_oconnor          0.0
# antonin_scalia              0.0
# anthony_m_kennedy      0.063963
# david_h_souter              0.0
# clarence_thomas        0.161368
# ruth_bader_ginsburg    0.115433
# stephen_g_breyer       0.117371
# john_g_roberts_jr      0.157707
# samuel_a_alito_jr      0.153816
# sonia_sotomayor        0.109104
# elena_kagan            0.125313
# neil_gorsuch                  1
# brett_m_kavanaugh      0.094173
# Name: neil_gorsuch, dtype: object
# Top words for j__ruth_bader_ginsburg: ['court', 'case', 'said', 'say', 'state', 'just', 'question', 'mr', 'don', 'think']
# Voting similarity with other Justices: john_paul_stevens      0.305733
# sandra_day_oconnor     0.019473
# antonin_scalia         0.418363
# anthony_m_kennedy      0.611045
# david_h_souter          0.25296
# clarence_thomas        0.546336
# ruth_bader_ginsburg           1
# stephen_g_breyer       0.847892
# john_g_roberts_jr      0.640763
# samuel_a_alito_jr      0.548036
# sonia_sotomayor        0.618519
# elena_kagan            0.525449
# neil_gorsuch           0.115433
# brett_m_kavanaugh      0.070753
# Name: ruth_bader_ginsburg, dtype: object
# Top words for j__samuel_a_alito_jr: ['say', 'case', 'think', 'court', 'don', 'state', 'going', 'question', 'just', 'does']
# Voting similarity with other Justices: john_paul_stevens      0.170684
# sandra_day_oconnor          0.0
# antonin_scalia         0.549219
# anthony_m_kennedy      0.670593
# david_h_souter         0.137448
# clarence_thomas         0.81132
# ruth_bader_ginsburg    0.548036
# stephen_g_breyer       0.583202
# john_g_roberts_jr       0.81213
# samuel_a_alito_jr             1
# sonia_sotomayor        0.390321
# elena_kagan            0.356378
# neil_gorsuch           0.153816
# brett_m_kavanaugh       0.10248
# Name: samuel_a_alito_jr, dtype: object
# Top words for j__sandra_day_oconnor: ['court', 'case', 'don', 'think', 'say', 'just', 'law', 'rule', 'yes', 'does']
# Voting similarity with other Justices: john_paul_stevens      0.019656
# sandra_day_oconnor            1
# antonin_scalia         0.020998
# anthony_m_kennedy      0.019441
# david_h_souter         0.022562
# clarence_thomas        0.018536
# ruth_bader_ginsburg    0.019473
# stephen_g_breyer       0.021085
# john_g_roberts_jr      0.019521
# samuel_a_alito_jr           0.0
# sonia_sotomayor             0.0
# elena_kagan                 0.0
# neil_gorsuch                0.0
# brett_m_kavanaugh           0.0
# Name: sandra_day_oconnor, dtype: object
# Top words for j__sonia_sotomayor: ['don', 'court', 'think', 'question', 'just', 'going', 'say', 'right', 'said', 'know']
# Voting similarity with other Justices: john_paul_stevens      0.060524
# sandra_day_oconnor          0.0
# antonin_scalia         0.246154
# anthony_m_kennedy      0.413836
# david_h_souter              0.0
# clarence_thomas        0.381275
# ruth_bader_ginsburg    0.618519
# stephen_g_breyer       0.592486
# john_g_roberts_jr       0.46641
# samuel_a_alito_jr      0.390321
# sonia_sotomayor               1
# elena_kagan            0.515204
# neil_gorsuch           0.109104
# brett_m_kavanaugh      0.066862
# Name: sonia_sotomayor, dtype: object
# Top words for j__stephen_g_breyer: ['say', 'don', 'think', 'right', 'know', 'just', 'case', 'says', 'mean', 'want']
# Voting similarity with other Justices: john_paul_stevens      0.303668
# sandra_day_oconnor     0.021085
# antonin_scalia         0.404179
# anthony_m_kennedy      0.638595
# david_h_souter         0.242326
# clarence_thomas        0.561664
# ruth_bader_ginsburg    0.847892
# stephen_g_breyer              1
# john_g_roberts_jr       0.67967
# samuel_a_alito_jr      0.583202
# sonia_sotomayor        0.592486
# elena_kagan            0.521288
# neil_gorsuch           0.117371
# brett_m_kavanaugh      0.076836
# Name: stephen_g_breyer, dtype: object

# %%
import networkx as nx
import plotly.graph_objects as go

# Step 1: Prepare the data
# Create a graph where nodes are Justices and edges represent shared words
G = nx.Graph()

# Add nodes (Justices)
for justice in top_words_per_justice.index:
    justice_name = justice.split('__')[-1]
    G.add_node(justice_name)

# Add edges based on shared words
for justice1 in top_words_per_justice.index:
    justice1_name = justice1.split('__')[-1]
    for justice2 in top_words_per_justice.index:
        justice2_name = justice2.split('__')[-1]
        if justice1_name != justice2_name:
            shared_words = set(top_words_per_justice[justice1]).intersection(set(top_words_per_justice[justice2]))
            if shared_words:
                # Add edge with weight proportional to the number of shared words
                G.add_edge(justice1_name, justice2_name, weight=len(shared_words))

# Step 2: Create a network graph
pos = nx.spring_layout(G)  # Layout for the graph

# Create edge traces with varying thickness and color based on weight
edge_trace = []
for edge in G.edges():
    x0, y0 = pos[edge[0]]
    x1, y1 = pos[edge[1]]
    weight = G[edge[0]][edge[1]]['weight']  # Get the weight (number of shared words)
    edge_trace.append(go.Scatter(
        x=[x0, x1],
        y=[y0, y1],
        mode='lines',
        line=dict(width=weight * 0.5, color='blue'),  # Thicker line for higher weight
        opacity=0.3,  # Adjust opacity for better visibility
        hoverinfo='text',
        text=f"Shared Words: {weight}",  # Display number of shared words on hover
        name=f"{edge[0]} - {edge[1]}"
    ))

# Create node trace
node_trace = go.Scatter(
    x=[pos[node][0] for node in G.nodes()],
    y=[pos[node][1] for node in G.nodes()],
    mode='markers+text',
    text=[node for node in G.nodes()],
    marker=dict(
        size=20,
        color='lightblue',  # Node color
        line=dict(width=2, color='lightblue')  # Node border
    ),
    textposition="top center",
    hoverinfo='text',
    textfont=dict(
        size=24,
        color='black',
        family='Arial Black'  # Use a bold font family
    )
)

# Create the figure
fig = go.Figure(data=edge_trace + [node_trace],
                layout=go.Layout(
                    title="Network Graph: Justices and Shared Words",
                    title_x=0.5,
                    title_font=dict(size=24),
                    showlegend=False,
                    hovermode='closest',
                    xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                    yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                    margin=dict(l=40, r=40, b=40, t=40),
                    paper_bgcolor='rgba(0,0,0,0)',
                    plot_bgcolor='rgba(0,0,0,0)'
                ))

fig.update_layout(
        width = 800,
        height = 800
    )

fig.write_image("network graph.png")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e94f253a-0a37-48ac-8dcd-5dd67de44ca9" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e94f253a-0a37-48ac-8dcd-5dd67de44ca9")) {                    Plotly.newPlot(                        "e94f253a-0a37-48ac-8dcd-5dd67de44ca9",                        [{"hoverinfo":"text","line":{"color":"blue","width":3.5},"mode":"lines","name":"anthony_m_kennedy - antonin_scalia","opacity":0.3,"text":"Shared Words: 7","x":[0.703476515371566,-0.2388126682857675],"y":[0.08995658108975348,-0.16053444273143316],"type":"scatter"},{"hoverinfo":"text","line":{"color":"blue","width":3.0},"mode":"lines","name":"anthony_m_kennedy - brett_m_kavanaugh","opacity":0.3,"text":"Shared Words: 6","x":[0.703476515371566,0.88296658232306],"y":[0.08995658108975348,0.4586118443492053],"type":"scatter"},{"hoverinfo":"text","line":{"color":"blue","width":2.5},"mode":"lines","name":"anthony_m_kennedy - clarence_thomas","opacity":0.3,"text":"Shared Words: 5","x":[0.703476515371566,0.4982911888797026],"y":[0.08995658108975348,-1.0],"type":"scatter"},{"hoverinfo":"text","line":{"color":"blue","width":3.0},"mode":"lines","name":"anthony_m_kennedy - david_h_souter","opacity":0.3,"text":"Shared Words: 6","x":[0.703476515371566,0.3725609760220846],"y":[0.08995658108975348,0.959775755488682],"type":"scatter"},{"hoverinfo":"text","line":{"color":"blue","width":2.5},"mode":"lines","name":"anthony_m_kennedy - elena_kagan","opacity":0.3,"text":"Shared Words: 5","x":[0.703476515371566,-0.2064644028161626],"y":[0.08995658108975348,-0.8212275366695125],"type":"scatter"},{"hoverinfo":"text","line":{"color":"blue","width":2.0},"mode":"lines","name":"anthony_m_kennedy - john_g_roberts_jr","opacity":0.3,"text":"Shared Words: 4","x":[0.703476515371566,-0.7114757235210462],"y":[0.08995658108975348,-0.6120123550044476],"type":"scatter"},{"hoverinfo":"text","line":{"color":"blue","width":3.0},"mode":"lines","name":"anthony_m_kennedy - john_paul_stevens","opacity":0.3,"text":"Shared Words: 6","x":[0.703476515371566,-0.422563854836321],"y":[0.08995658108975348,0.30042538468678176],"type":"scatter"},{"hoverinfo":"text","line":{"color":"blue","width":4.0},"mode":"lines","name":"anthony_m_kennedy - neil_gorsuch","opacity":0.3,"text":"Shared Words: 8","x":[0.703476515371566,0.1948599626736302],"y":[0.08995658108975348,0.3347528887851539],"type":"scatter"},{"hoverinfo":"text","line":{"color":"blue","width":4.0},"mode":"lines","name":"anthony_m_kennedy - ruth_bader_ginsburg","opacity":0.3,"text":"Shared Words: 8","x":[0.703476515371566,0.18636502945187697],"y":[0.08995658108975348,-0.4593434930283931],"type":"scatter"},{"hoverinfo":"text","line":{"color":"blue","width":4.0},"mode":"lines","name":"anthony_m_kennedy - samuel_a_alito_jr","opacity":0.3,"text":"Shared Words: 8","x":[0.703476515371566,0.5975803883896735],"y":[0.08995658108975348,-0.29420459269842125],"type":"scatter"},{"hoverinfo":"text","line":{"color":"blue","width":3.0},"mode":"lines","name":"anthony_m_kennedy - sandra_day_oconnor","opacity":0.3,"text":"Shared Words: 6","x":[0.703476515371566,-0.7886690350380435],"y":[0.08995658108975348,0.544021393380028],"type":"scatter"},{"hoverinfo":"text","line":{"color":"blue","width":3.0},"mode":"lines","name":"anthony_m_kennedy - sonia_sotomayor","opacity":0.3,"text":"Shared Words: 6","x":[0.703476515371566,-0.1674555963227315],"y":[0.08995658108975348,0.7631214499652647],"type":"scatter"},{"hoverinfo":"text","line":{"color":"blue","width":2.5},"mode":"lines","name":"anthony_m_kennedy - stephen_g_breyer","opacity":0.3,"text":"Shared Words: 5","x":[0.703476515371566,-0.9006593622915131],"y":[0.08995658108975348,-0.10334287761266955],"type":"scatter"},{"hoverinfo":"text","line":{"color": ...
